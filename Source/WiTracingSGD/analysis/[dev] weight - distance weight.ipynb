# %% [markdown]
# # [dev] 1. distance weight

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import signals
from IPython.display import clear_output

# %%
RSS_RANGE = np.arange(-100,-40,1)
weights = 1.0 / signals.calc_distance_with(0.1, RSS_RANGE)

# %% [markdown]
# ## Visualize Weights

# %%
plt.figure(figsize=(20,5))
plt.plot(RSS_RANGE, weights)
plt.show()
